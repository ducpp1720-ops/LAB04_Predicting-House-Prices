# %% [markdown]
# # Lab 04 — PyTorch MLP Regression
#
# Clean-run notebook for Practice Exercise 4. It uses the real Boston Housing dataset from `data/raw/boston_housing.csv`. No synthetic fallback is used.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == "notebooks": ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / "src"))
from train import main
print("Project root:", ROOT)
# Out:
# Project root: /mnt/data/audit_current/Lab4_PyTorch_MLP_Regression_FINAL

# %%
main()
# Out:
#                                MAE        MSE      RMSE        R2
# MLP                       2.506221  14.949417  3.866448  0.796146
# Linear Regression         3.189087  24.291044  4.928595  0.668761
# Decision Tree Regression  2.308157   8.553907  2.924706  0.883357
# Random Forest Regression  2.031838   8.418204  2.901414  0.885207
# ACTUAL TRAINING PASS
